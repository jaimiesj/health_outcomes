# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('DataSets/gapminder_alcohol.csv')

# %%
dataclean
# Out:
#          country  alcconsumption  incomeperperson  suicideper100th  \
# 1        Albania            7.29      1914.996551         7.699330
# 2        Algeria            0.69      2231.993335         4.848770
# 4         Angola            5.57      1381.004268        14.554677
# 6      Argentina            9.35     10749.419240         7.765584
# 7        Armenia           13.66      1326.741757         3.741588
# ..           ...             ...              ...              ...
# 207    Venezuela            7.60      5528.363114         4.119620
# 208      Vietnam            3.91       722.807559        11.653322
# 210  Yemen, Rep.            0.20       610.357367         6.265789
# 211       Zambia            3.56       432.226337        12.019036
# 212     Zimbabwe            4.96       320.771890        13.905267
#
#      employrate  urbanrate
# 1     51.400002      46.72
# 2     50.500000      65.22
# 4     75.699997      56.70
# 6     58.400002      92.00
# ...

# %%
dataclean=data.dropna(axis=0)

# %%
dataclean.columns
# Out:
# Index(['country', 'alcconsumption', 'incomeperperson', 'suicideper100th',
#        'employrate', 'urbanrate'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['country', 'alcconsumption', 'incomeperperson', 'suicideper100th',
#        'employrate', 'urbanrate'],
#       dtype='object')

# %%
X=dataclean[['alcconsumption','employrate']]

# %%
y=dataclean['suicideper100th']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
cdf=pd.DataFrame(lm.coef_,X.columns,columns=['coeff'])

# %%
cdf
# Out:
#                    coeff
# alcconsumption  0.402970
# employrate      0.011281

# %%
#Predictions
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([10.47230868, 10.81226548, 14.27134862,  7.50515555, 12.04615641,
#        13.95542117,  9.06334009,  9.74854677,  7.56671554,  9.84898697,
#        12.61095042,  7.70763335,  7.20731904, 12.01002894,  7.56318683,
#        10.49097691, 10.85706141,  8.18133259,  7.27532292, 13.26265154,
#         8.251963  , 13.71623404, 12.64370256,  7.53450969,  9.70296123,
#        12.46443729,  9.25324144, 10.35203583, 10.91573342, 10.69891025,
#        12.03247448, 10.05530481,  9.4495685 ,  7.57917488, 16.45885222,
#         9.86284948, 10.30305681, 11.29838779, 10.25517875, 10.08866148,
#         8.72406941,  9.07606991,  9.47483858, 13.05100891,  8.38656308,
#         7.38752735, 10.68302197,  8.1550243 , 13.7531421 ,  7.4013672 ,
#         9.43907682, 12.24230288,  9.10704867, 13.33774919, 11.16444661,
#         8.15602624, 11.81421639,  8.76852684, 12.74747731,  9.68909413,
#         7.97210864,  8.28096957, 13.85420039, 11.42994198,  9.99777447])

# %%
predictions = pd.Series(predictions)
pd.concat([predictions, y_test], axis = 1)
# Out:
#              0  suicideper100th
# 0    10.472309              NaN
# 1    10.812265              NaN
# 2    14.271349         4.848770
# 3     7.505156              NaN
# 4    12.046156              NaN
# ..         ...              ...
# 196        NaN         3.563325
# 203        NaN         9.927033
# 208        NaN        11.653322
# 210        NaN         6.265789
# 212        NaN        13.905267
#
# [110 rows x 2 columns]

# %%
y_test
# Out:
# 94     18.946930
# 37     10.171870
# 59     16.959240
# 141     9.257976
# 179     5.888479
#          ...
# 176     4.484753
# 91      5.931845
# 110    33.341860
# 17     15.953850
# 68      1.574350
# Name: suicideper100th, Length: 65, dtype: float64

# %%
plt.scatter(y_test,predictions)

# %%
sns.displot(((y_test-predictions)))

# %%
sns.displot(dataclean['suicideper100th'],kde=True)

# %%
sns.set_theme(style="whitegrid")

rs = np.random.RandomState(365)
values = rs.randn(365, 4).cumsum(axis=0)
dates = pd.date_range("1 1 2016", periods=365, freq="D")
data = pd.DataFrame(values, dates, columns=["A", "B", "C", "D"])
data = data.rolling(7).mean()

sns.lineplot(data=data, palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.set_theme(style="white")

# Load the example mpg dataset
mpg = sns.load_dataset("mpg")

# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="horsepower", y="mpg", hue="origin", size="weight",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=mpg)
